# %%
import { document } from 'jsr:@ry/jupyter-helper';
import pl from 'npm:nodejs-polars';
import * as Plot from 'npm:@observablehq/plot';
let { html, md, display } = Deno.jupyter;

# %%
type Seriesify<T extends Record<string, pl.DataType>> = {
  [key in keyof T]: key extends string ? pl.Series<T[key], key> : pl.Series<T[key]>;
};

# %%
type Ascent = {
  created_at: pl.Datetime;
  ascendable_id: pl.Int64;
  ascendable_name: pl.String;
  ascendable_type: pl.Categorical; //'GymBoulder';
  grading_system: pl.Categorical; //'font';
  grade: pl.String;
  difficulty: pl.String;
  type: pl.Categorical; // 'rp' | 'f';
  sub_type: pl.String;
  tries: pl.Int64;
};

let ascents = pl.readJSON('./data/ascents_56689.jsonl', {
  inferSchemaLength: null,
  format: 'lines',
}) as pl.DataFrame<Seriesify<Ascent>>;

ascents = ascents
  .withColumns(
    ascents.getColumn('created_at').str.strptime(pl.Datetime, '%Y-%m-%d %H:%M:%S %z').cast(pl.Datetime('ms')),
    ascents.getColumn('updated_at').str.strptime(pl.Datetime, '%Y-%m-%d %H:%M:%S %z').cast(pl.Datetime('ms')),
    ascents.getColumn('date').str.strptime(pl.Datetime, '%Y-%m-%d %H:%M:%S %z').cast(pl.Datetime('ms')),
    ascents.getColumn('ascendable_type').cast(pl.Categorical),
    ascents.getColumn('grading_system').cast(pl.Categorical),
  )
  .withColumns(pl.col('date').date.year().alias('year'))
  // remove repeat ascents
  .unique({ subset: 'ascendable_id', keep: 'first' });
# Out:
# <table><thead><tr><th>tries</th><th>protection</th><th>virtual</th><th>safety_issues</th><th>archived_at</th><th>vl_user_id</th><th>eight_a_ascendable_id</th><th>comment</th><th>parent_id</th><th>features</th><th>perceived_hardness</th><th>eight_a_id</th><th>updated_at</th><th>project</th><th>grade</th><th>vl_ascendable_id</th><th>date</th><th>difficulty</th><th>ascendable_id</th><th>shade</th><th>height</th><th>vl_parent_id</th><th>ascendable_type</th><th>eight_a_user_id</th><th>path</th><th>ascendable_height</th><th>hold_color</th><th>steepness</th><th>repeat</th><th>created_at</th><th>sub_type</th><th>sits</th><th>user_id</th><th>style</th><th>eight_a_parent_id</th><th>ascendable_filter</th><th>ascendable_name</th><th>eight_a_logbook</th><th>grading_system</th><th>parent_name</th><th>rating</th><th>recommended</th><th>id</th><th>vl_id</th><th>score</th><th>exposition</th><th>provider</th><th>repeats</th><th>type</th><th>year</th></tr></thead><tbody><tr><td>3</td><td>0</td><td>false</td><td>null</td><td>null</td><td>56295</td><td>null</td><td>null</td><td>69</td><td>null</td><td>0</td><td>null</td><td>Tue Oct 24 2023 22:20:16 GMT+0200 (Central European Summer Time)</td><td>false</td><td>vl-23</td><td>null</td><td>Thu Jul 25 2019 14:00:00 GMT+0200 (Central European Summer Time)</td><td>7A</td><td>88503</td><td>null</td><td>4</td><td>null</td><td>GymBoulder</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>false</td><td>Sun Aug 11 2019 21:46:07 GMT+0200 (Central European Summer Time)</td><td></td><td>0</td><td>56689</td><td></td><td>null</td><td>null</td><td>Purple</td><td>false</td><td>font</td><td>Klättercentret Solna</td><td>3</td><td>false</td><td>1664978</td><td>1616356</td><td>700</td><td>null</td><td>verticallife</td><td>0</td><td>rp</td><td>2019</td></tr><tr><td>1</td><td>null</td><td>false</td><td>0</td><td>null</td><td>56295</td><td>null</td><td>null</td><td>69</td><td>0</td><td>0</td><td>null</td><td>Wed Oct 25 2023 01:58:12 GMT+0200 (Central European Summer Time)</td><td>false</td><td>vl-21</td><td>null</td><td>Thu May 11 2023 14:00:00 GMT+0200 (Central European Summer Time)</td><td>6C</td><td>432201</td><td>0</td><td>4</td><td>null</td><td>GymBoulder</td><td>null</td><td>null</td><td>0</td><td>null</td><td>0</td><td>false</td><td>Thu May 11 2023 22:19:58 GMT+0200 (Central European Summer Time)</td><td></td><td>0</td><td>56689</td><td></td><td>null</td><td>null</td><td>Magenta 1</td><td>false</td><td>font</td><td>Klättercentret Solna</td><td>2</td><td>false</td><td>5676147</td><td>5541539</td><td>653</td><td>0</td><td>verticallife</td><td>0</td><td>f</td><td>2023</td></tr><tr><td>1</td><td>null</td><td>false</td><td>null</td><td>null</td><td>56295</td><td>null</td><td>null</td><td>69</td><td>null</td><td>0</td><td>null</td><td>Mon Jul 08 2024 20:51:36 GMT+0200 (Central European Summer Time)</td><td>false</td><td>vl-14</td><td>null</td><td>Mon Jul 08 2024 14:00:00 GMT+0200 (Central European Summer Time)</td><td>5+</td><td>514109</td><td>null</td><td>4</td><td>null</td><td>GymBoulder</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>false</td><td>Mon Jul 08 2024 20:51:36 GMT+0200 (Central European Summer Time)</td><td></td><td>0</td><td>56689</td><td></td><td>null</td><td>null</td><td>Red</td><td>false</td><td>font</td><td>Klättercentret Solna</td><td>null</td><td>false</td><td>15486690</td><td>6737235</td><td>353</td><td>null</td><td>verticallife</td><td>0</td><td>f</td><td>2024</td></tr><tr><td>1</td><td>0</td><td>false</td><td>null</td><td>null</td><td>56295</td><td>null</td><td>null</td><td>68</td><td>null</td><td>0</td><td>null</td><td>Tue Oct 24 2023 22:20:56 GMT+0200 (Central European Summer Time)</td><td>false</td><td>vl-21</td><td>null</td><td>Sun Oct 20 2019 14:00:00 GMT+0200 (Central European Summer Time)</td><td>6C</td><td>101353</td><td>null</td><td>4</td><td>null</td><td>GymBoulder</td><td>null</td><td>null</td><td>null</td><td>null</td><td>0</td><td>false</td><td ...

# %%
type Boulder = {
  id: pl.Int64;
  route_setter: pl.String;
  sector_name: pl.String;
  gym_wall_name: pl.String;
  set_at: pl.Datetime;
  route_card_label: pl.String;
};

let boulders = pl
  .readJSON('./data/gym_boulders.jsonl', {
    inferSchemaLength: null,
    format: 'lines',
  })
  .withColumns(
    pl.col('route_card_label').str.slice(0, 3),
    pl.col('set_at').str.strptime(pl.Datetime, '%Y-%m-%d %H:%M:%S %z').cast(pl.Datetime('ms')),
    pl.col('id').alias('nid'),
  ) as pl.DataFrame<Seriesify<Boulder>>;

# %%
let detailedAscents = ascents
  .join(boulders, {
    leftOn: 'ascendable_id',
    rightOn: 'nid',
  })
  .sort(pl.col('date'));

# %%
let boulderScores = [
  { score: 12, v: 'VB', font: '2' },
  { score: 18, v: 'VB', font: '2+' },
  { score: 24, v: 'VB+', font: '3' },
  { score: 30, v: 'VB+', font: '3+' },
  { score: 36, v: 'V0-', font: '4' },
  { score: 42, v: 'V0', font: '4+' },
  { score: 48, v: 'V1', font: '5' },
  { score: 54, v: 'V2', font: '5+' },
  { score: 60, v: 'V3', font: '6a' },
  { score: 66, v: 'V3', font: '6a+' },
  { score: 72, v: 'V4', font: '6b' },
  { score: 78, v: 'V4', font: '6b+' },
  { score: 84, v: 'V5', font: '6c' },
  { score: 90, v: 'V5', font: '6c+' },
  { score: 96, v: 'V6', font: '7a' },
  { score: 102, v: 'V7', font: '7a+' },
  { score: 108, v: 'V7', font: '7b' },
  { score: 114, v: 'V8', font: '7b+' },
  { score: 120, v: 'V9', font: '7c' },
  { score: 126, v: 'V10', font: '7c+' },
].map((grade) => ({ ...grade, font: grade.font.toUpperCase() }));
let gradeToNumber = boulderScores.reduce((acc, grade) => {
  acc[grade.font] = grade.score;
  return acc;
}, {});

gradeToNumber;
# Out:
# {
#   "2": 12,
#   "3": 24,
#   "4": 36,
#   "5": 48,
#   "2+": 18,
#   "3+": 30,
#   "4+": 42,
#   "5+": 54,
#   "6A": 60,
#   "6A+": 66,
#   "6B": 72,
#   "6B+": 78,
#   "6C": 84,
#   "6C+": 90,
#   "7A": 96,
#   "7A+": 102,
#   "7B": 108,
#   "7B+": 114,
#   "7C": 120,
#   "7C+": 126
# }

# %%
detailedAscents = detailedAscents.withColumns(
  pl.col('difficulty').replace({ old: gradeToNumber }).cast(pl.Float32).alias('numberDifficulty'),
  pl.col('type').replace(['f', 'rp'], ['flash', 'redpoint']),
);
# Out:
# <table><thead><tr><th>tries</th><th>protection</th><th>virtual</th><th>safety_issues</th><th>archived_at</th><th>vl_user_id</th><th>eight_a_ascendable_id</th><th>comment</th><th>parent_id</th><th>features</th><th>perceived_hardness</th><th>eight_a_id</th><th>updated_at</th><th>project</th><th>grade</th><th>vl_ascendable_id</th><th>date</th><th>difficulty</th><th>ascendable_id</th><th>shade</th><th>height</th><th>vl_parent_id</th><th>ascendable_type</th><th>eight_a_user_id</th><th>path</th><th>ascendable_height</th><th>hold_color</th><th>steepness</th><th>repeat</th><th>created_at</th><th>sub_type</th><th>sits</th><th>user_id</th><th>style</th><th>eight_a_parent_id</th><th>ascendable_filter</th><th>ascendable_name</th><th>eight_a_logbook</th><th>grading_system</th><th>parent_name</th><th>rating</th><th>recommended</th><th>id</th><th>vl_id</th><th>score</th><th>exposition</th><th>provider</th><th>repeats</th><th>type</th><th>year</th><th>virtual_right</th><th>gallery</th><th>set_at</th><th>color_2</th><th>reference_width</th><th>gym_wall_id</th><th>updated_at_right</th><th>sector_id</th><th>share_url</th><th>gym</th><th>notes</th><th>grade_right</th><th>difficulty_right</th><th>display_route_setter</th><th>traverse</th><th>path_right</th><th>route_setter</th><th>steepness_right</th><th>created_at_right</th><th>style_right</th><th>expiration_date</th><th>sector_name</th><th>item_type</th><th>sit_down_start</th><th>grading_system_right</th><th>grade_proposals</th><th>line_number</th><th>color_1</th><th>archived</th><th>hold_manufacturer</th><th>gym_wall_name</th><th>name</th><th>two_start_holds</th><th>id_right</th><th>topo_num</th><th>stats</th><th>route_card_label</th><th>parent_name_right</th><th>gym_id</th><th>topo</th><th>numberDifficulty</th></tr></thead><tbody><tr><td>1</td><td>0</td><td
# <table><thead><tr><th>route_setter</th><th>count</th></tr></thead><tbody><tr><td>Anton Cuevas</td><td>550</td></tr><tr><td>Benjamin Schlobohm</td><td>394</td></tr><tr><td>N.N.</td><td>360</td></tr><tr><td>James Thanawat</td><td>314</td></tr><tr><td>Emil  Abrahamsson</td><td>297</td></tr><tr><td>Robert  Rundin </td><td>253</td></tr><tr><td>Nikken Daniels</td><td>244</td></tr><tr><td>Stina Dorwarth</td><td>220</td></tr><tr><td>Silver Breiktopf</td><td>185</td></tr><tr><td>Sebastian Dahlgren </td><td>181</td></tr><tr><td>Zac Chattaway</td><td>177</td></tr><tr><td>Felipe Ignacio Palma Hernandez</td><td>171</td></tr><tr><td>Tobias Lindgren</td><td>141</td></tr><tr><td>Cordelia Jansson</td><td>78</td></tr><tr><td>Emil Bergman</td><td>75</td></tr><tr><td>Isabelle Fugelstad</td><td>47</td></tr><tr><td>Felicia Ekblom</td><td>38</td></tr><tr><td>Niclas Henriksson</td><td>38</td></tr><tr><td>Julia Chew</td><td>33</td></tr><tr><td>Sophie Machaczek</td><td>30</td></tr><tr><td>Rickard Sjöquist</td><td>26</td></tr><tr><td>Scott Mooney</td><td>25</td></tr><tr><td>Fredrik Serlachius</td><td>21</td></tr><tr><td>anton linden</td><td>19</td></tr><tr><td>Axel Malmström</td><td>14</td></tr><tr><td>Johanna Sörbom</td><td>13</td></tr><tr><td>Hannes Platon</td><td>8</td></tr><tr><td>Björn Nilsson</td><td>7</td></tr><tr><td>Elias Karlsson</td><td>6</td></tr><tr><td>Samuel Wingårdh</td><td>6</td></tr><tr><td>Elise Nordström</td><td>5</td></tr><tr><td>Jimmie Myrthil</td><td>4</td></tr><tr><td>Andreas Åhlfeldt</td><td>4</td></tr><tr><td>Alex Chapman</td><td>4</td></tr><tr><td>Team  KV</td><td>3</td></tr><tr><td>Felix Panduro</td><td>3</td></tr><tr><td>Ida Lidström</td><td>2</td></tr><tr><td>Victor Sandberg</td><td>2</td></tr><tr><td>Rebecka Gullberg</td><td>2</td></tr><tr><td>Rickard Söderström</td><td>2</td></tr><tr><td>Robin Dahlberg</td><td>2</td></tr><tr><td>Michael Skagvik</td><td>1</td></tr><tr><td>Peter Bosma</td><td>1</td></tr><tr><td>Ivan Monroy</td><td>1</td></tr></tbody></table>

# %%
let baseWidth = 640;
let ascentTypeColorDomain = { domain: ['flash', 'redpoint'], range: ['#ffd800', '#ff5151'] };

# %%
let groupings = [
  {
    name: 'Everything',
    y: 'difficulty',
    fill: 'type',
  },
  {
    name: 'By year',
    y: 'difficulty',
    fy: 'year',
    fill: 'type',
  },
  {
    name: 'By gym',
    y: 'difficulty',
    fx: 'year',
    fy: 'parent_name',
    fill: 'type',
  },
  {
    name: 'By route setter',
    y: 'difficulty',
    fx: 'year',
    fy: 'route_setter',
    fill: 'type',
    sort: { fy: '-x', reduce: 'count' },
  },
];
for (const grouping of groupings) {
  await display(md`## ${grouping.name}`);
  await display(
    Plot.plot({
      grid: true,
      width: baseWidth * 2,
      color: { legend: true, type: 'categorical', ...ascentTypeColorDomain },
      marginRight: 150,
      marks: [
        Plot.frame(),
        Plot.barX(detailedAscents.toRecords(), Plot.groupY({ x: 'count' }, { ...grouping, title: 'count' })),
      ],
      y: { type: 'band', reverse: true },
      document,
    }),
  );
}
# Out:
# ## Everything
# <figure style="max-width:initial" class="plot-d6a7b5-figure"><div class="plot-d6a7b5-swatches plot-d6a7b5-swatches-wrap"><style>:where(.plot-d6a7b5-swatches) {
#   font-family: system-ui, sans-serif;
#   font-size: 10px;
#   margin-bottom: 0.5em;
# }
# :where(.plot-d6a7b5-swatch > svg) {
#   margin-right: 0.5em;
#   overflow: visible;
# }
# :where(.plot-d6a7b5-swatches-wrap) {
#   display: flex;
#   align-items: center;
#   min-height: 33px;
#   flex-wrap: wrap;
# }
# :where(.plot-d6a7b5-swatches-wrap .plot-d6a7b5-swatch) {
#   display: inline-flex;
#   align-items: center;
#   margin-right: 1em;
# }</style><span class="plot-d6a7b5-swatch"><svg fill="#ffd800" height="15" width="15"><rect height="100%" width="100%" /></svg>flash</span><span class="plot-d6a7b5-swatch"><svg fill="#ff5151" height="15" width="15"><rect height="100%" width="100%" /></svg>redpoint</span></div><svg viewBox="0 0 1280 500" height="500" width="1280" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
#   --plot-background: white;
#   display: block;
#   height: auto;
#   height: intrinsic;
#   max-width: 100%;
# }
# :where(.plot-d6a7b5 text),
# :where(.plot-d6a7b5 tspan) {
#   white-space: pre;
# }</style><g transform="translate(0,9)" stroke-opacity="0.1" stroke="currentColor" aria-hidden="true" aria-label="y-grid"><line y2="26" y1="26" x2="1130" x1="40" /><line y2="46" y1="46" x2="1130" x1="40" /><line y2="66" y1="66" x2="1130" x1="40" /><line y2="86" y1="86" x2="1130" x1="40" /><line y2="106" y1="106" x2="1130" x1="40" /><line y2="126" y1="126" x2="1130" x1="40" /><line y2="146" y1="146" x2="1130" x1="40" /><line y2="166" y1="166" x2="1130" x1="40" /><line y2="186" y1="186" x2="1130" x1="40" /><line y2="206" y1="206" x2="1130" x1="40" /><line y2="226" y1="226" x2="1130" x1="40" /><line y2="246" y1="246" x2="1130" x1="40" /><line y2="266" y1="266" x2="1130" x1="40" /><line y2="286" y1="286" x2="1130" x1="40" /><line y2="306" y1="306" x2="1130" x1="40" /><line y2="326" y1="326" x2="1130" x1="40" /><line y2="346" y1="346" x2="1130" x1="40" /><line y2="366" y1="366" x2="1130" x1="40" /><line y2="386" y1="386" x2="1130" x1="40" /><line y2="406" y1="406" x2="1130" x1="40" /><line y2="426" y1="426" x2="1130" x1="40" /><line y2="446" y1="446" x2="1130" x1="40" /></g><g transform="translate(0,9)" stroke="currentColor" fill="none" aria-hidden="true" aria-label="y-axis tick"><path d="M0,0L-6,0" transform="translate(40,26)" /><path d="M0,0L-6,0" transform="translate(40,46)" /><path d="M0,0L-6,0" transform="translate(40,66)" /><path d="M0,0L-6,0" transform="translate(40,86)" /><path d="M0,0L-6,0" transform="translate(40,106)" /><path d="M0,0L-6,0" transform="translate(40,126)" /><path d="M0,0L-6,0" transform="translate(40,146)" /><path d="M0,0L-6,0" transform="translate(40,166)" /><path d="M0,0L-6,0" transform="translate(40,186)" /><path d="M0,0L-6,0" transform="translate(40,206)" /><path d="M0,0L-6,0" transform="translate(40,226)" /><path d="M0,0L-6,0" transform="translate(40,246)" /><path d="M0,0L-6,0" transform="translate(40,266)" /><path d="M0,0L-6,0" transform="translate(40,286)" /><path d="M0,0L-6,0" transform="translate(40,306)" /><path d="M0,0L-6,0" transform="translate(40,326)" /><path d="M0,0L-6,0" transform="translate(40,346)" /><path d="M0,0L-6,0" transform="translate(40,366)" /><path d="M0,0L-6,0" transform="translate(40,386)" /><path d="M0,0L-6,0" transform="translate(40,406)" /><path d="M0,0L-6,0" transform="translate(40,426)" /><path d="M0,0L-6,0" transform="translate(40,446)" /></g><g transform="translate(-9,9)" text-anchor="end" aria-label="y-axis tick label"><text transform="translate(40,26)" y="0.32em">Svart tejp</text><text transform="translate(40,46)" y="0.32em">Röd tejp</text><text transform="translate(40,66)" y="0.32em">Grön tejp</text><text transform="translate(40,86)" y="0.32em">Blå tejp</text><text transform="translate(40,106)" y="0.32em">7C</text><text transform="translate(40,126)" y="0.32em">7B+</text><text transform="translate(40,146)" y="0.32em">7B</text><text transform="translate(40,166)" y="0.32em">7A+</text><text transform="translate(40,186)" y="0.32em">7A</text><text transform="translate(40,206)" y="0.32em">6C+</text><text transform="translate(40,226)" y="0.32em">6C</text><text transform="translate(40,246)" y="0.32em">6B+</text><text transform="translate(40,266)" y="0.32em">6B</text><text transform="translate(40,286)" y="0.32em">6A+</text><text transform="translate(40,306)" y="0.32em">6A</text><text transform="translate(40,326)" y="0.32em">5+</text><text transform="translate(40,346)" y="0.32em">5</text><text transform="translate(40,366)" y="0.32em">4+</text><text transform="translate(40,386)" y="0.32em">4</text><text transform="translate(40,406)" y="0.32em">3+</text><text transform="translate(40,426)" y="0.32em">3</text><text transform="translate(40,446)" y="0.32em">2</text></g><g transform="translate(-37,0)" aria-label="y-axis label"><text transform="translate(40,245) rotate(-90)" y="0.71em">difficulty</text></g><g stroke-opacity="0.1" stroke="currentColor" aria-hidden="true" aria-label="x-grid"><line y2="470" y1="20" x2="40" x1="40" /><line y2="470" y1="20" x2="94.22885572139305" x1="94.228855 ...
# ## By year
# <figure style="max-width:initial" class="plot-d6a7b5-figure"><div class="plot-d6a7b5-swatches plot-d6a7b5-swatches-wrap"><style>:where(.plot-d6a7b5-swatches) {
#   font-family: system-ui, sans-serif;
#   font-size: 10px;
#   margin-bottom: 0.5em;
# }
# :where(.plot-d6a7b5-swatch > svg) {
#   margin-right: 0.5em;
#   overflow: visible;
# }
# :where(.plot-d6a7b5-swatches-wrap) {
#   display: flex;
#   align-items: center;
#   min-height: 33px;
#   flex-wrap: wrap;
# }
# :where(.plot-d6a7b5-swatches-wrap .plot-d6a7b5-swatch) {
#   display: inline-flex;
#   align-items: center;
#   margin-right: 1em;
# }</style><span class="plot-d6a7b5-swatch"><svg fill="#ffd800" height="15" width="15"><rect height="100%" width="100%" /></svg>flash</span><span class="plot-d6a7b5-swatch"><svg fill="#ff5151" height="15" width="15"><rect height="100%" width="100%" /></svg>redpoint</span></div><svg viewBox="0 0 1280 1260" height="1260" width="1280" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
#   --plot-background: white;
#   display: block;
#   height: auto;
#   height: intrinsic;
#   max-width: 100%;
# }
# :where(.plot-d6a7b5 text),
# :where(.plot-d6a7b5 tspan) {
#   white-space: pre;
# }</style><g transform="translate(9,0)" aria-label="fy-axis tick label"><g transform="translate(0,1)" text-anchor="start"><text transform="translate(1130,99)" y="0.32em">2,019</text></g><g transform="translate(0,176)" text-anchor="start"><text transform="translate(1130,99)" y="0.32em">2,020</text></g><g transform="translate(0,351)" text-anchor="start"><text transform="translate(1130,99)" y="0.32em">2,021</text></g><g transform="translate(0,526)" text-anchor="start"><text transform="translate(1130,99)" y="0.32em">2,022</text></g><g transform="translate(0,701)" text-anchor="start"><text transform="translate(1130,99)" y="0.32em">2,023</text></g><g transform="translate(0,876)" text-anchor="start"><text transform="translate(1130,99)" y="0.32em">2,024</text></g><g transform="translate(0,1051)" text-anchor="start"><text transform="translate(1130,99)" y="0.32em">2,025</text></g></g><g transform="translate(147,0)" aria-label="fy-axis label"><text transform="translate(1130,625) rotate(-90)">year</text></g><g transform="translate(0,3)" aria-hidden="true" aria-label="y-grid"><g transform="translate(0,1)" stroke-opacity="0.1" stroke="currentColor"><line y2="22" y1="22" x2="1130" x1="40" /><line y2="29" y1="29" x2="1130" x1="40" /><line y2="36" y1="36" x2="1130" x1="40" /><line y2="43" y1="43" x2="1130" x1="40" /><line y2="50" y1="50" x2="1130" x1="40" /><line y2="57" y1="57" x2="1130" x1="40" /><line y2="64" y1="64" x2="1130" x1="40" /><line y2="71" y1="71" x2="1130" x1="40" /><line y2="78" y1="78" x2="1130" x1="40" /><line y2="85" y1="85" x2="1130" x1="40" /><line y2="92" y1="92" x2="1130" x1="40" /><line y2="99" y1="99" x2="1130" x1="40" /><line y2="106" y1="106" x2="1130" x1="40" /><line y2="113" y1="113" x2="1130" x1="40" /><line y2="120" y1="120" x2="1130" x1="40" /><line y2="127" y1="127" x2="1130" x1="40" /><line y2="134" y1="134" x2="1130" x1="40" /><line y2="141" y1="141" x2="1130" x1="40" /><line y2="148" y1="148" x2="1130" x1="40" /><line y2="155" y1="155" x2="1130" x1="40" /><line y2="162" y1="162" x2="1130" x1="40" /><line y2="169" y1="169" x2="1130" x1="40" /></g><g transform="translate(0,176)" stroke-opacity="0.1" stroke="currentColor"><line y2="22" y1="22" x2="1130" x1="40" /><line y2="29" y1="29" x2="1130" x1="40" /><line y2="36" y1="36" x2="1130" x1="40" /><line y2="43" y1="43" x2="1130" x1="40" /><line y2="50" y1="50" x2="1130" x1="40" /><line y2="57" y1="57" x2="1130" x1="40" /><line y2="64" y1="64" x2="1130" x1="40" /><line y2="71" y1="71" x2="1130" x1="40" /><line y2="78" y1="78" x2="1130" x1="40" /><line y2="85" y1="85" x2="1130" x1="40" /><line y2="92" y1="92" x2="1130" x1="40" /><line y2="99" y1="99" x2="1130" x1="40" /><line y2="106" y1="106" x2="1130" x1="40" /><line y2="113" y1="113" x2="1130" x1="40" /><line y2="120" y1="120" x2="1130" x1="40" /><line y2="127" y1="127" x2="1130" x1="40" /><line y2="134" y1="134" x2="1130" x1="40" /><line y2="141" y1="141" x2="1130" x1="40" /><line y2="148" y1="148" x2="1130" x1="40" /><line y2="155" y1="155" x2="1130" x1="40" /><line y2="162" y1="162" x2="1130" x1="40" /><line y2="169" y1="169" x2="1130" x1="40" /></g><g transform="translate(0,351)" stroke-opacity="0.1" stroke="currentColor"><line y2="22" y1="22" x2="1130" x1="40" /><line y2="29" y1="29" x2="1130" x1="40" /><line y2="36" y1="36" x2="1130" x1="40" /><line y2="43" y1="43" x2="1130" x1="40" /><line y2="50" y1="50" x2="1130" x1="40" /><line y2="57" y1="57" x2="1130" x1="40" /><line y2="64" y1="64" x2="1130" x1="40" /><line y2="71" y1="71" x2="1130" x1="40" /><line y2="78" y1="78" x2="1130" x1="40" /><line y2="85" y1="85" x2="1130" x1="40" /><line y2="92" y1="92" x2="1130" x1="40" /><line y2="99" y1="99" x2="1130" x1="40" /><line y2="106" y1="106" x2="1130" x1="40" /><line y2="113" y1="113" x2="1130" x1="40" /><line y2="120" y1="120" x2="1130" x1="40" /><line y2="127" y1="127" x2="1130" x1="40" /><line y2="134" y1="134" x2="1130" x1="40" /><line y2="141" y1="141" x2="1130" x1="40" /><line y2="148" y1="148" x2="1130"  ...
# ## By gym
# <figure style="max-width:initial" class="plot-d6a7b5-figure"><div class="plot-d6a7b5-swatches plot-d6a7b5-swatches-wrap"><style>:where(.plot-d6a7b5-swatches) {
#   font-family: system-ui, sans-serif;
#   font-size: 10px;
#   margin-bottom: 0.5em;
# }
# :where(.plot-d6a7b5-swatch > svg) {
#   margin-right: 0.5em;
#   overflow: visible;
# }
# :where(.plot-d6a7b5-swatches-wrap) {
#   display: flex;
#   align-items: center;
#   min-height: 33px;
#   flex-wrap: wrap;
# }
# :where(.plot-d6a7b5-swatches-wrap .plot-d6a7b5-swatch) {
#   display: inline-flex;
#   align-items: center;
#   margin-right: 1em;
# }</style><span class="plot-d6a7b5-swatch"><svg fill="#ffd800" height="15" width="15"><rect height="100%" width="100%" /></svg>flash</span><span class="plot-d6a7b5-swatch"><svg fill="#ff5151" height="15" width="15"><rect height="100%" width="100%" /></svg>redpoint</span></div><svg viewBox="0 0 1280 1290" height="1290" width="1280" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
#   --plot-background: white;
#   display: block;
#   height: auto;
#   height: intrinsic;
#   max-width: 100%;
# }
# :where(.plot-d6a7b5 text),
# :where(.plot-d6a7b5 tspan) {
#   white-space: pre;
# }</style><g transform="translate(9,0)" aria-label="fy-axis tick label"><g transform="translate(945,1)" text-anchor="start"><text transform="translate(181,123.5)" y="0.32em">Karbin Klätterhall</text></g><g transform="translate(945,209)" text-anchor="start"><text transform="translate(181,123.5)" y="0.32em">Klättercentret Gallerian</text></g><g transform="translate(945,417)" text-anchor="start"><text transform="translate(181,123.5)" y="0.32em">Klättercentret Solna</text></g><g transform="translate(945,625)" text-anchor="start"><text transform="translate(181,123.5)" y="0.32em">Klättercentret Telefonplan</text></g><g transform="translate(945,833)" text-anchor="start"><text transform="translate(181,123.5)" y="0.32em">
# <figure style="max-width:initial" class="plot-d6a7b5-figure"><div class="plot-d6a7b5-swatches plot-d6a7b5-swatches-wrap"><style>:where(.plot-d6a7b5-swatches) {
#   font-family: system-ui, sans-serif;
#   font-size: 10px;
#   margin-bottom: 0.5em;
# }
# :where(.plot-d6a7b5-swatch > svg) {
#   margin-right: 0.5em;
#   overflow: visible;
# }
# :where(.plot-d6a7b5-swatches-wrap) {
#   display: flex;
#   align-items: center;
#   min-height: 33px;
#   flex-wrap: wrap;
# }
# :where(.plot-d6a7b5-swatches-wrap .plot-d6a7b5-swatch) {
#   display: inline-flex;
#   align-items: center;
#   margin-right: 1em;
# }</style><span class="plot-d6a7b5-swatch"><svg fill="#ffd800" height="15" width="15"><rect height="100%" width="100%" /></svg>flash</span><span class="plot-d6a7b5-swatch"><svg fill="#ff5151" height="15" width="15"><rect height="100%" width="100%" /></svg>redpoint</span></div><svg viewBox="0 0 1280 1290" height="1290" width="1280" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
#   --plot-background: white;
#   display: block;
#   height: auto;
#   height: intrinsic;
#   max-width: 100%;
# }
# :where(.plot-d6a7b5 text),
# :where(.plot-d6a7b5 tspan) {
#   white-space: pre;
# }</style><g transform="translate(9,0)" aria-label="fy-axis tick label"><g transform="translate(945,0)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">James Thanawat</text></g><g transform="translate(945,28)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">N.N.</text></g><g transform="translate(945,56)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Anton Cuevas</text></g><g transform="translate(945,84)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Sebastian Dahlgren </text></g><g transform="translate(945,112)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Robert  Rundin </text></g><g transform="translate(945,140)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Felipe Ignacio Palma Hernandez</text></g><g transform="translate(945,168)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Benjamin Schlobohm</text></g><g transform="translate(945,196)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Tobias Lindgren</text></g><g transform="translate(945,224)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Zac Chattaway</text></g><g transform="translate(945,252)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Silver Breiktopf</text></g><g transform="translate(945,280)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Emil  Abrahamsson</text></g><g transform="translate(945,308)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Nikken Daniels</text></g><g transform="translate(945,336)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Stina Dorwarth</text></g><g transform="translate(945,364)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Cordelia Jansson</text></g><g transform="translate(945,392)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Emil Bergman</text></g><g transform="translate(945,420)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Isabelle Fugelstad</text></g><g transform="translate(945,448)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Julia Chew</text></g><g transform="translate(945,476)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Scott Mooney</text></g><g transform="translate(945,504)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Sophie Machaczek</text></g><g transform="translate(945,532)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Niclas Henriksson</text></g><g transform="translate(945,560)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Felicia Ekblom</text></g><g transform="translate(945,588)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Rickard Sjöquist</text></g><g transform="translate(945,616)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Fredrik Serlachius</text></g><g transform="translate(945,644)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">anton linden</text></g><g transform="translate(945,672)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Axel Malmström</text></g><g transform="translate(945,700)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Johanna Sörbom</text></g><g transform="translate(945,728)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Hannes Platon</text></g><g transform="translate(945,756)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Elias Karlsson</text></g><g transform="translate(945,784)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Samuel Wingårdh</text></g><g transform="translate(945,812)" text-anchor="start"><text transform="translate(181,42.5)" y="0.32em">Elise Nordström</text></g><g transform="translate(945,840)" text-anchor="start"><text transfo ...

# %%
await display(
  md`
## Poor man's CPR
  `,
);

Plot.plot(
  (() => {
    const data = detailedAscents
      .groupBy(pl.col('date').date.strftime('%Y-%U').alias('week'), 'type')
      .agg(
        pl.col('date').first(),
        pl.col('difficulty').min().alias('difficultyMin'),
        pl.col('difficulty').max().alias('difficultyMax'),
        pl.col('numberDifficulty').min().sub(3).alias('numberDifficultyMin'),
        pl.col('numberDifficulty').max().alias('numberDifficultyMax'),
        pl.col('date').count().alias('count'),
      );

    return {
      figure: true,
      grid: true,
      color: { legend: true, type: 'categorical', ...ascentTypeColorDomain },
      width: 1500,
      y: {
        ticks: boulderScores.filter((grade) => grade.font <= '7C').map((grade) => grade.score),
        tickFormat: (v) => boulderScores.find(({ score }) => v === score)?.font,
      },
      marks: [
        Plot.frame(),
        Plot.rectY(
          data.toRecords(),

          {
            interval: 'week',
            x: 'date',

            y1: 'numberDifficultyMin',
            y2: 'numberDifficultyMax',
            fill: 'type',
            title: (d) => {
              if (d.difficultyMin === d.difficultyMax) return d.difficultyMin;
              return `${d.difficultyMin} - ${d.difficultyMax}`;
            },
            inset: 1,
            mixBlendMode: 'color-dodge',
          },
        ),
        /*
        Plot.rectY(data.toRecords(), { interval: 'week', x: 'date', y: 'count', fill: 'gray' }),
        Plot.text(data.toRecords(), {
          x: 'date',
          y: 'count',
          text: 'count',
          lineAnchor: 'bottom',
        }),
        */
      ],
      document,
    };
  })(),
);
# Out:
# ## Poor man's CPR
# <figure style="max-width:initial" class="plot-d6a7b5-figure"><div class="plot-d6a7b5-swatches plot-d6a7b5-swatches-wrap"><style>:where(.plot-d6a7b5-swatches) {
#   font-family: system-ui, sans-serif;
#   font-size: 10px;
#   margin-bottom: 0.5em;
# }
# :where(.plot-d6a7b5-swatch > svg) {
#   margin-right: 0.5em;
#   overflow: visible;
# }
# :where(.plot-d6a7b5-swatches-wrap) {
#   display: flex;
#   align-items: center;
#   min-height: 33px;
#   flex-wrap: wrap;
# }
# :where(.plot-d6a7b5-swatches-wrap .plot-d6a7b5-swatch) {
#   display: inline-flex;
#   align-items: center;
#   margin-right: 1em;
# }</style><span class="plot-d6a7b5-swatch"><svg fill="#ffd800" height="15" width="15"><rect height="100%" width="100%" /></svg>flash</span><span class="plot-d6a7b5-swatch"><svg fill="#ff5151" height="15" width="15"><rect height="100%" width="100%" /></svg>redpoint</span></div><svg viewBox="0 0 1500 400" height="400" width="1500" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
#   --plot-background: white;
#   display: block;
#   height: auto;
#   height: intrinsic;
#   max-width: 100%;
# }
# :where(.plot-d6a7b5 text),
# :where(.plot-d6a7b5 tspan) {
#   white-space: pre;
# }</style><g stroke-opacity="0.1" stroke="currentColor" aria-hidden="true" aria-label="y-grid"><line y2="360.5405405405405" y1="360.5405405405405" x2="1480" x1="40" /><line y2="341.6216216216216" y1="341.6216216216216" x2="1480" x1="40" /><line y2="322.7027027027027" y1="322.7027027027027" x2="1480" x1="40" /><line y2="303.7837837837838" y1="303.7837837837838" x2="1480" x1="40" /><line y2="284.86486486486484" y1="284.86486486486484" x2="1480" x1="40" /><line y2="265.94594594594594" y1="265.94594594594594" x2="1480" x1="40" /><line y2="247.02702702702703" y1="247.02702702702703" x2="1480" x1="40" /><line y2="228.10810810810807" y1="228.10810810810807" x2="1480" x1="40" /><line y2="209.1891891891892" y1="209.1891891891892" x2="1480" x1="40" /><line y2="190.27027027027026" y1="190.27027027027026" x2="1480" x1="40" /><line y2="171.35135135135135" y1="171.35135135135135" x2="1480" x1="40" /><line y2="152.43243243243242" y1="152.43243243243242" x2="1480" x1="40" /><line y2="133.51351351351352" y1="133.51351351351352" x2="1480" x1="40" /><line y2="114.5945945945946" y1="114.5945945945946" x2="1480" x1="40" /><line y2="95.67567567567568" y1="95.67567567567568" x2="1480" x1="40" /><line y2="76.75675675675676" y1="76.75675675675676" x2="1480" x1="40" /><line y2="57.83783783783784" y1="57.83783783783784" x2="1480" x1="40" /><line y2="38.91891891891892" y1="38.91891891891892" x2="1480" x1="40" /><line y2="20" y1="20" x2="1480" x1="40" /></g><g stroke="currentColor" fill="none" aria-hidden="true" aria-label="y-axis tick"><path d="M0,0L-6,0" transform="translate(40,360.5405405405405)" /><path d="M0,0L-6,0" transform="translate(40,341.6216216216216)" /><path d="M0,0L-6,0" transform="translate(40,322.7027027027027)" /><path d="M0,0L-6,0" transform="translate(40,303.7837837837838)" /><path d="M0,0L-6,0" transform="translate(40,284.86486486486484)" /><path d="M0,0L-6,0" transform="translate(40,265.94594594594594)" /><path d="M0,0L-6,0" transform="translate(40,247.02702702702703)" /><path d="M0,0L-6,0" transform="translate(40,228.10810810810807)" /><path d="M0,0L-6,0" transform="translate(40,209.1891891891892)" /><path d="M0,0L-6,0" transform="translate(40,190.27027027027026)" /><path d="M0,0L-6,0" transform="translate(40,171.35135135135135)" /><path d="M0,0L-6,0" transform="translate(40,152.43243243243242)" /><path d="M0,0L-6,0" transform="translate(40,133.51351351351352)" /><path d="M0,0L-6,0" transform="translate(40,114.5945945945946)" /><path d="M0,0L-6,0" transform="translate(40,95.67567567567568)" /><path d="M0,0L-6,0" transform="translate(40,76.75675675675676)" /><path d="M0,0L-6,0" transform="translate(40,57.83783783783784)" /><path d="M0,0L-6,0" transform="translate(40,38.91891891891892)" /><path d="M0,0L-6,0" transform="translate(40,20)" /></g><g transform="translate(-9,0)" font-variant="tabular-nums" text-anchor="end" aria-label="y-axis tick label"><text transform="translate(40,360.5405405405405)" y="0.32em">2</text><text transform="translate(40,341.6216216216216)" y="0.32em">2+</text><text transform="translate(40,322.7027027027027)" y="0.32em">3</text><text transform="translate(40,303.7837837837838)" y="0.32em">3+</text><text transform="translate(40,284.86486486486484)" y="0.32em">4</text><text transform="translate(40,265.94594594594594)" y="0.32em">4+</text><text transform="translate(40,247.02702702702703)" y="0.32em">5</text><text transform="translate(40,228.10810810810807)" y="0.32em">5+</text><text transform="translate(40,209.1891891891892)" y="0.32em">6A</text><text transform="translate(40,190.27027027027026)" y="0.32em">6A+</text><text transform="translate(40,171.35135135135135)" y="0.32em">6B</text><text transform="translate(40,152.43243243243242)" y="0.32em">6B+</text><text transform="translate(40,133.51351351351352)" y="0.32em">6C</text><text transform="translate(40,114.5945945945946)" y="0.32em">6C+</text><text transform="translate(40,95.67567567567568)" y="0.32em">7A</text><text transform="translate(40,76.75675675675676)" y ...

# %%
Plot.plot(
  (() => {
    const data = detailedAscents
      .groupBy(pl.col('date').date.strftime('%Y-%U').alias('grouped'))
      .agg(
        pl.col('date').first().cast(pl.Date).alias('date'),
        pl.col('numberDifficulty').sum().alias('totalNumberDifficulty'),
        pl.col('date').count().alias('count'),
        pl.col('difficulty'),
      )
      .toRecords();
    return {
      figure: true,
      color: { scheme: 'YlGn', domain: [0, 3000] },
      width: 1500,
      marks: [
        Plot.barX(data, {
          interval: 'week',
          x: 'date',
          fill: 'totalNumberDifficulty',
          title: (d) =>
            Object.entries(
              d.difficulty.reduce((acc, grade) => {
                if (!acc[grade]) {
                  acc[grade] = 0;
                }
                acc[grade] += 1;
                return acc;
              }, {}),
            )
              .toSorted((a, b) => a[0].localeCompare(b[0]))
              .reduce((acc, ascents) => [...acc, `${ascents[0]} x${ascents[1]}`], [] as string[])
              .join('; '),
        }),
      ],
      document,
    };
  })(),
);
# Out:
# <figure style="max-width:initial" class="plot-d6a7b5-figure"
30)"><tspan y="0.71em" x="0">Jan</tspan><tspan dy="1em" x="0">2024</tspan></text><text transform="translate(1229.1505791505792,30)" y="0.71em">Apr</text><text transform="translate(1293.2722007722007,30)" y="0.71em">Jul</text><text transform="translate(1358.0984555984555,30)" y="0.71em">Oct</text><text transform="translate(1422.9247104247104,30)"><tspan y="0.71em" x="0">Jan</tspan><tspan dy="1em" x="0">2025</tspan></text></g><g aria-label="bar"><rect fill="rgb(10, 109, 57)" height="29.5" y="0.5" width="3.932432432432421" x="138.8783783783784"><title>4 x1; 5 x1; 5+ x4; 6A x4; 6A+ x5; 6B x2; 6B+ x3; 6C x5; 6C+ x4; 7A x1; 7A+ x2; 7B x1; 7B+ x1</title></rect><rect fill="rgb(221, 241, 167)" height="29.5" y="0.5" width="3.932432432432506" x="977.3918918918919"><title>3 x1; 5 x2; 6A x1; 6B x1; 6B+ x2; 6C x2; 7B x1</title></rect><rect fill="rgb( ...

# %%
import * as d3 from 'npm:d3';

Plot.plot(
  (() => {
    const data = detailedAscents
      .groupBy(pl.col('date').date.strftime('%Y-%U').alias('grouped'))
      .agg(
        pl.col('date').first().date.strftime('%Y-%m-%d'),
        pl.col('numberDifficulty').sum().alias('totalNumberDifficulty'),
        pl.col('date').count().alias('count'),
        pl.col('difficulty'),
      )
      .toRecords();
    return {
      figure: true,
      x: { tickFormat: (d) => `Week ${d + 1}`, tickRotate: 90 },
      y: { tickFormat: '', tickSize: 0 },
      color: { scheme: 'YlGn', domain: [0, 3000] },
      marginBottom: 47,
      marks: [
        Plot.cell(data, {
          x: (d) => d3.utcWeek.count(d3.utcYear(new Date(d.date)), new Date(d.date)),
          y: (d) => new Date(d.date).getUTCFullYear(),
          fill: 'totalNumberDifficulty',
          title: (d) =>
            Object.entries(
              d.difficulty.reduce((acc, grade) => {
                if (!acc[grade]) {
                  acc[grade] = 0;
                }
                acc[grade] += 1;
                return acc;
              }, {}),
            )
              .toSorted((a, b) => a[0].localeCompare(b[0]))
              .reduce((acc, ascents) => [...acc, `${ascents[0]} x${ascents[1]}`], [] as string[])
              .join('; '),
          inset: 1,
        }),
      ],
      document,
    };
  })(),
);
# Out:
# <figure style="max-width:initial" class="plot-d6a7b5-figure"><svg viewBox="0 0 640 217" height="217" width="640" text-anchor="middle" font-size="10" font-family="system-ui, sans-serif" fill="currentColor" class="plot-d6a7b5"><style>:where(.plot-d6a7b5) {
#   --plot-background: white;
#   display: block;
#   height: auto;
#   height: intrinsic;
#   max-width: 100%;
# }
# :where(.plot-d6a7b5 text),
# :where(.plot-d6a7b5 tspan) {
#   white-space: pre;
# }</style><g transform="translate(-9,9.5)" text-anchor="end" aria-label="y-axis tick label"><text transform="translate(40,23)" y="0.32em">2019</text><text transform="translate(40,44)" y="0.32em">2020</text><text transform="translate(40,65)" y="0.32em">2021</text><text transform="translate(40,86)" y="0.32em">2022</text><text transform="translate(40,107)" y="0.32em">2023</text><text transform="translate(40,128)" y="0.32em">2024</text><text transform="translate(40,149)" y="0.32em">2025</text></g><g transform="translate(5,0)" stroke="currentColor" fill="none" aria-hidden="true" aria-label="x-axis tick"><path d="M0,0L0,6" transform="translate(50,170)" /><path d="M0,0L0,6" transform="translate(61,170)" /><path d="M0,0L0,6" transform="translate(72,170)" /><path d="M0,0L0,6" transform="translate(83,170)" /><path d="M0,0L0,6" trans